# %% [markdown]
# 과제 : 깃허브에 올리기
# https://banapresso.com/store
#
# 1. 바나프레소 홈페이지에서 매장별 이름, 주소를 크롤링
# 2. 지오코딩을 통해 주소를 위, 경도로 변환
# 3. 해당 컬럼을 데이터프레임에 저장
#     인덱스  매장이름  매장주소   위도  경도
# 4. folium 라이브러리 모듈을 이용하여 지도에 각 매장을 출력

# %%
import requests 
from bs4 import BeautifulSoup 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import numpy as np
import pandas as pd
import time
import folium

# %%
url = "https://banapresso.com/store"

driver = webdriver.Chrome('D:/Coding/Classroom/python/Day2/chromedriver.exe') 
driver.get(url)

request = requests.get(url)
print(request)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   This is separate from the ipykernel package so we can avoid doing imports until
# <Response [200]>

# %%
total_stores = []
is_end = False
next_page = False
page = 1
index = 0

while not is_end :
    time.sleep(0.5)

    if page != 6 and page != 1:
        driver.find_element('xpath', '//*[@id="contents"]/article/div/section[1]/div/div[1]/div[3]/ul/li[{}]/a'.format(page)).click()
    if page == 4 and next_page == True:
        is_end = True
    elif page == 6 :
        driver.find_element('xpath', '//*[@id="contents"]/article/div/section[1]/div/div[1]/div[3]/span/a').click()
        next_page = True
        page = 1

    html = driver.page_source
    soup = BeautifulSoup(html)

    shop_list = soup.find('div', {'class' : 'store_shop_list'})

    store_name = shop_list.select('.store_name_map>b')
    store_location = shop_list.select('.store_name_map>i')
    store_address = shop_list.select('.store_name_map>span')
    print(len(store_name), len(store_location), len(store_address))
    for i in range(len(shop_list.select("ul>li"))):
        if store_name[i].text.strip() and store_location[i].text.strip() and store_address[i].text.strip():
            store = [index, store_name[i].text.strip(), store_location[i].text.strip(), store_address[i].text.strip()]
            total_stores.append(store)
            index += 1
    page += 1
# Out:
# 10 10 10
# 10 10 10
# 10 10 10
# 10 10 10
# 10 10 10
# 10 10 10
# 10 10 10
# 10 10 10
# 5 5 5

# %%
print(total_stores)
# Out:
# [[0, 'MODERN GREY', '가산디지털단지역점', '서울시 금천구 가산동 60-3'], [1, 'HALF MOON', '강남구청점', '서울 강남구 청담동 45-4'], [2, 'FULL OF COZINESS', '강남역사거리점', '서울특별시 강남구 역삼동 820-10'], [3, 'NY Grand Central', '강남역점', '서울 강남구 역삼동822-7'], [4, 'GLEN CHECK', '강남점', '서울 강남구 테헤란로4길 46 (역삼동 826-37) 쌍용 플래티넘, 1층'], [5, 'SECRET GARDEN', '강남효성점', '서울 강남구 역삼동 825-24'], [6, 'BLOOM', '강동역점', '서울 강동구 천호동 447'], [7, 'NATURAL CLASSIC', '거여역점', '서울특별시 송파구 거여동 37-6'], [8, 'GOLDISH', '건대역점', '서울 광진구 아차산로 221 (화양동 7-4)'], [9, 'BLOOM', '경희대점', '서울 동대문구 경희대로4길 1'], [10, 'CLASSIC CITY', '광명하안점', '광명시 하안동 36-2'], [11, 'PEBBLE', '교대사거리점', '서울 서초구 서초동 1598-1'], [12, 'ORIGINAL PINK', '교대역점', '서울 서초구 반포대로30길 82'], [13, 'ORIGINAL PINK', '교대점', '서울 서초구 서초대로54길 27, 1층'], [14, 'THE GARDEN PLACE', '구로비즈메트로점', '서울시 구로구 구로동 851번지 한화비즈메트로1차 109호'], [15, 'COFFEE STATION', '구로지플러스점', '서울시 구로구 구로동 222-31'], [16, 'PINK AGORA', '국기원사거리점', '서울 강남구 테헤란로8길 26 (역삼동827-48)'], [17, 'SECRET GAREDN', '길동역점', '서울 강동구 양재대로 1490 (길동 366-5)'], [18, 'COZY MOOD', '낙성대역점', '서울시 관악구 봉천동 1658-19'], [19, 'ORIGINAL PINK', '남부터미널점', '서울 서초구 효령로57길 1'], [20, 'COFFEE STATION', '대치선릉점', '서울특별시 강남구 대치동 890-45'], [21, 'Florescence', '대치역점', '서울 강남구 대치동 507'], [22, 'SEXY BACK', '대치은마점', '서울 강남구 도곡로 451 (대치동 941-22) 한나빌딩, 1층'], [23, 'PLAY FUN', '대치점', '서울 강남구 테헤란로 84길 14 (대치동 942-19), 1층'], [24, 'NATURE ROOFTOP', '대치포스코점', '서울 강남구 테헤란로78길 16 (대치동 891-44) 노벨빌딩 증축동, 1층/2층'], [25, 'SEE THROUGH', '도곡역점', '서울특별시 강남구 남부순환로 2909 여천빌딩'], [26, 'made in korea', '독도점', '경상북도 울릉군 울릉읍 독도리 산 1-96'], [27, 'WITH NATURE', '뚝섬역점', '서울시 성동구 성수동1가 13-164'], [28, 'PINK SUNRISE', '마곡나루역점', '서울시 강서구 마곡동 760-1'], [29, 'PINK BIRDCAGE', '무교점', '서울특별시 중구 다동 155'], [30, 'SECRET GARDEN', '문정역점', '서울 송파구 법원로128 (문정동642-3, SKV1빌딩 1층)'], [31, 'GRAY FACTORY', '미아사거리역점', '서울시 강북구 미아동 60-5'], [32, 'SOFT LAYERS', '방배역점', '서울시 서초구 방배동 909-8'], [33, 'COZY MOOD', '보라매역점', '서울시 동작구 대방동 400-3'], [34, 'LITTLE FOREST', '사당역점', '서울 서초구 방배동444-15'], [35, 'Rabbit in Wonderland', '삼성점', '서울특별시 강남구 삼성동 157-4 1층'], [36, 'URBAN TERRACE', '삼성중앙역점', '서울 강남구 삼성동 51-2 1층'], [37, '뉴욕자취방', '삼성타운점', '서울 서초구 서초대로78길 26 (서초동1327-7)'], [38, 'BLUE GREEN', '상암DMC점', '서울 마포구 상암동 1605'], [39, 'NATURE GARDEN', '서초법원점', '서울시 서초구 서초동 1554-5 아스트라 101호, 102호'], [40, 'SUNSET PINK', '서초위브점', '서울 서초구 서초동 1362'], [41, 'PINK CLOUD', '서초점', '서울 서초구 서초대로 254 B105호 (서초동, 오퓨런스)'], [42, 'TRAVEL THROUGH TIME', '선릉공원점', '서울 강남구 삼성동 142-46'], [43, 'CITY GARDEN', '선릉역사거리점', '서울 강남구 역삼동 705-19'], [44, 'ORIGINAL PINK', '선릉역점', '서울 강남구 테헤란로51길 7 (역삼동702-30)'], [45, 'BANA STATION', '선릉위워크점', '서울특별시 강남구 대치동 889-41'], [46, 'ORIGINAL WHITE', '선릉점', '서울 강남구 언주로 98길 26 (역삼동 700-35), 1층'], [47, 'PURE WHITE', '선정릉점', '서울 강남구 선릉로 577 (역삼동 682-20) POS TOWER, 1층'], [48, 'COFFEE BASKET', '세관사거리점', '서울 강남구 언주로 702 (논현동115-13)'], [49, 'SWEET CASTLE', '수내역점', '주소 경기 성남시 분당구 수내로46번길 26'], [50, 'TERRACE IN THE GARDEN', '숙대입구역점', '서울특별시 용산구 갈월동 92 1층'], [51, 'BRICK HOUSE', '신논현역점', '서울 서초구 서초동 1303-1'], [52, 'PINK GARDEN PLACE', '신촌로터리점', '서울특별시 마포구 노고산동 57-14'], [53, 'WARM EMBRACE', '신촌점', '서울시 서대문구 창천동 13-29'], [54, 'VENUS SKY', '양재역점', '서울 강남구 강남대로 240 (도곡동 953-1, 양재SK허브)'], [55, 'NEW-TRO', '양재점', '서울 서초구  강남대로 221  (양재동 23)'], [56, 'STAY IN THE MOMENT', '언주역점', '서울시 강남구 역삼동 650'], [57, 'FLOWER OF DESERT', '여의도역점', '서울특별시 영등포구 여의도동 26-1'], [58, 'STAY WARM', '여의도KBS점', '서울시 영등포구 여의도동 17번지 더샵아일랜드파크 102동 117호~118호'], [59, 'PURE WHITE', '역삼대로점', '서울 강남구 논현로 427-1 (역삼동 738-27)'], [60, 'COZY HOUSE', '역삼삼보점', '서울특별시 강남구 역삼동 647-13'], [61, 'WOODY NOTE', '역삼시티점', '서울 강남구 논현로85길 52 B102호'], [62, 'ORIGINAL WHITE', '역삼역점', '서울 강남구 강남대로 94길 95 (역삼동 644-19), 1층'], [63, 'BUCOLIC', '역삼초교사거리점', '서울 강남구 역삼동829-17'], [64, 'CITY BROWN', '역삼GFC점', '서울 강남구 테헤란로26길 10 (역삼동 736-55) 성보빌딩, 1층'], [65, 'ORIGINAL WHITE', '역삼GS점', '서울 강남구 논현로 94길 13'], [66, 'BREEZE', '을지병원사거리점', '서울 강남구 논현동6-21'], [67, 'BRound', '이대점', '서울 마포구 대현동 56-74'], [68, 'KEEP WARM', '이수역점', '서울 동작구 사당동 134-3'], [69, 'ORIGINAL PINK', '잠실새내점', '서울 송파구 석촌호수로 64 (잠실동 208-16)'] ...

# %%
df = pd.DataFrame(total_stores)
df.columns = ['index', '매장이름', '매장위치', '매장주소']
print(df)
# Out:
#     index              매장이름       매장위치  \
# 0       0       MODERN GREY  가산디지털단지역점
# 1       1         HALF MOON      강남구청점
# 2       2  FULL OF COZINESS    강남역사거리점
# 3       3  NY Grand Central       강남역점
# 4       4        GLEN CHECK        강남점
# ..    ...               ...        ...
# 79     79      AURORA DREAM       학동역점
# 80     80     SECRET GARDEN       한티역점
# 81     81       DRAW A WAVE       합정역점
# 82     82     MODERN FRENCH    회기역사거리점
# 83     83       MODERN GREY      AK금정점
#
#                                          매장주소
# 0                            서울시 금천구 가산동 60-3
# 1                             서울 강남구 청담동 45-4
# 2                        서울특별시 강남구 역삼동 820-10
# 3                             서울 강남구 역삼동822-7
# 4   서울 강남구 테헤란로4길 46 (역삼동 826-37) 쌍용 플래티넘, 1층
# ..                                        ...
# 79                            서울 강남구 논현동 87-5
# 80                     서울 강남구 선릉로311, 한티빌딩 1층
# 81                              서울 마포구 양화로 72
# 82                    서울 동대문구 회기로 176 (회기동81)
# 83             경기도 군포시 금정동 689번지 AK플라자 금정점 2층
#
# [84 rows x 4 columns]

# %%
add  = df['매장주소']
add
add.to_csv("./address.csv", index=False, encoding="ms949")

# %%
pos = pd.read_csv("./address2.csv", encoding="ms949")   
pos
# Out:
#                                          매장주소         위도          경도
# 0                            서울시 금천구 가산동 60-3  37.481048  126.886407
# 1                             서울 강남구 청담동 45-4  37.518456  127.046621
# 2                        서울특별시 강남구 역삼동 820-10  37.498893  127.027734
# 3                             서울 강남구 역삼동822-7  37.498980  127.029554
# 4   서울 강남구 테헤란로4길 46 (역삼동 826-37) 쌍용 플래티넘, 1층  37.495292  127.030314
# ..                                        ...        ...         ...
# 79                            서울 강남구 논현동 87-5  37.514457  127.031367
# 80                     서울 강남구 선릉로311, 한티빌딩 1층  37.497647  127.051884
# 81                              서울 마포구 양화로 72  37.550800  126.916718
# 82                    서울 동대문구 회기로 176 (회기동81)  37.590105  127.055367
# 83             경기도 군포시 금정동 689번지 AK플라자 금정점 2층  37.373049  126.944514
#
# [84 rows x 3 columns]

# %%
bana_df = pd.merge(df, pos, on='매장주소', how='inner')

# %%
bana_df
# Out:
#     index              매장이름       매장위치  \
# 0       0       MODERN GREY  가산디지털단지역점
# 1       1         HALF MOON      강남구청점
# 2       2  FULL OF COZINESS    강남역사거리점
# 3       3  NY Grand Central       강남역점
# 4       4        GLEN CHECK        강남점
# ..    ...               ...        ...
# 79     79      AURORA DREAM       학동역점
# 80     80     SECRET GARDEN       한티역점
# 81     81       DRAW A WAVE       합정역점
# 82     82     MODERN FRENCH    회기역사거리점
# 83     83       MODERN GREY      AK금정점
#
#                                          매장주소         위도          경도
# 0                            서울시 금천구 가산동 60-3  37.481048  126.886407
# 1                             서울 강남구 청담동 45-4  37.518456  127.046621
# 2                        서울특별시 강남구 역삼동 820-10  37.498893  127.027734
# 3                             서울 강남구 역삼동822-7  37.498980  127.029554
# 4   서울 강남구 테헤란로4길 46 (역삼동 826-37) 쌍용 플래티넘, 1층  37.495292  127.030314
# ..                                        ...        ...         ...
# 79                            서울 강남구 논현동 87-5  37.514457  127.031367
# 80                     서울 강남구 선릉로311, 한티빌딩 1층  37.497647  127.051884
# 81                              서울 마포구 양화로 72  37.550800  126.916718
# 82                    서울 동대문구 회기로 176 (회기동81)  37.590105  127.055367
# 83             경기도 군포시 금정동 689번지 AK플라자 금정점 2층  37.373049  126.944514
#
# [84 rows x 6 columns]

# %%
data = bana_df
bana_map = folium.Map(location = [data['위도'].mean(), data['경도'].mean()], zoom_start=12)

for i in data.index:
  bana_name = data.loc[i, "매장이름"] + ' - ' + data.loc[i, '매장주소'] 
  popup = folium.Popup(bana_name, max_width=500)
  folium.Marker(location=[data.loc[i, '위도'], data.loc[i, '경도']], popup=popup).add_to(bana_map)

# %%
bana_map.save('./bana_map.html')
bana_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1075e37de0c44ebc15dfaebf8ffe380 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1075e37de0c44ebc15dfaebf8ffe380&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c1075e37de0c44ebc15dfaebf8ffe380 = L.map(
#                 &quot;map_c1075e37de0c44ebc15dfaebf8ffe380&quot;,
#                 {
#                     center: [37.4463941904762, 127.03496970595238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a51fb1ccda90a96d08da15449bfa4a7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c1075e37de0c44ebc15dfaebf8ffe380);
#
#
#             var marker_86d97939d5d215856193436e0c8b0124 = L.marker(
#                 [37.481048, 126.8864071],
#                 {}
#             ).addTo(map_c1075e37de0c44ebc15dfaebf8ffe380);
#
#
#         var popup_13234523b100b834b84d9565ae6c8b1f = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_c5cd1479c550fc64c94f3caab7e58823 = $(`&lt;div id=&quot;html_c5cd1479c550fc64c94f3caab7e58823&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MODERN GREY - 서울시 금천구 가산동 60-3&lt;/div&gt;`)[0];
#             popup_13234523b100b834b84d9565ae6c8b1f.setContent(html_c5cd1479c550fc64c94f3caab7e58823);
#
#
#         marker_86d97939d5d215856193436e0c8b0124.bindPopup(popup_13234523b100b834b84d9565ae6c8b1f)
#         ;
#
#
#
#
#             var marker_c48a059226084658dd57e0c194c99205 = L.marker(
#                 [37.5184555, 127.046621],
#                 {}
#             ).addTo(map_c1075e37de0c44ebc15dfaebf8ffe380);
#
#
#         var popup_c75f55602d0f82081f55af7755211876 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_a4d2a8610830f7244f9db26068bfb5ee = $(`&lt;div id=&quot;html_a4d2a8610830f7244f9db26068bfb5ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;HALF MOON - 서울 강남구 청담동 45-4&lt;/div&gt;`)[0];
#             popup_c75f55602d0f82081f55af7755211876.setContent(html_a4d2a8610830f7244f9db26068bfb5ee);
#
#
#         marker_c48a059226084658dd57e0c194c99205.bindPopup(popup_c75f55602d0f82081f55af7755211876)
#         ;
#
#
#
#
#             var marker_ea2de8184c9b921ae82268f7233877e0 = L.marker(
#                 [37.4988929, 127.0277344],
#                 {}
#             ).addTo(map_c1075e37de0c44ebc15dfaebf8ffe380);
#
#
#         var popup_6a10549a27056d864b897441ded3eda8 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_5fca1fd65068cca275e6bc5fd4b5d1e7 = $(`&lt;div id=&quot;html_5fca1fd65068cca275e6bc5fd4b5d1e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FULL OF COZINESS - 서울특별시 강남구 역삼동 820-10&lt;/div&gt;`)[0];
#             popup_6a10549a27056d864b897441ded3eda8.setContent(html_5fca1fd65068cca275e6bc5fd4b5d1e7);
#
#
#         marker_ea2de8184c9b921ae82268f7233877e0.bindPopup(popup_6a10549a27056d864b897441ded3eda8)
#         ;
#
#
#
#
#             var marker_d6e1939cf9f6a286963161f2cf564a15 = L.marker(
#                 [37.49898, 127.029554],
#                 {}
#             ).addTo(map_c1075e37de0c44ebc15dfaebf8ffe380);
#
#
#         var popup_a6d7bc37007cbdff00af900640da35e2 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_b668676fd70e380df22eeb4375530cd9 = $(`&lt;div id=&quot;html_b668676fd70e380df22eeb4375530cd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NY Grand Central - 서울 강남구 역삼동822-7&lt;/div&gt;`)[0];
#             popup_a6d7bc37007cbdff00af900640da35e2.setContent(html_b668676fd70e380df22eeb4375530cd9);
#
#
#         marker_d6e1939cf9f6a286963161f2cf564a15.bindPopup(popup_a6d7bc37007cbdff00af900640da35e2)
#         ;
#
#
#
#
#             var marker_995fefb82620717f231940e5c8e9e9f7 = L.marker(
#                 [37.4952919, 127.0303142],
#                 {}
#             ).addTo(map_c1075e37de0c44ebc15dfaebf8ffe380);
#
#
#         var popup_d58ffa4e4bc75cd700f490438b87221f = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_1ecceb95d187a5f275498894f8b44738 = $(`&lt;div id=&quot;html_1ecceb95d187a5f275498894f8b44738&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GLEN CHECK - 서울 강남구 테헤란로4길 46 (역삼동 826-37) 쌍용 플래티넘, 1층&lt;/div&gt;`)[0];
#             popup_d58ffa4e4bc75cd700f490438b87221f.setContent(html_1ecceb95d187a5f275498894f8b44738);
#
#
#         marker_995fefb82620717f231940e5c8e9e9f7.bindPopup(popup_d58ffa4e4bc75cd700f490438b87221f)
#         ;
#
#
#
#
#             var marker_bdc291c797e5b7aa3d73a29c7d36ba94 = L.marker(
#                 [37.4969451, 127.0297387],
#                 {}
#             ).addTo(map_c1075e37de0c44ebc15dfaebf8ffe380);
#
#
#         var popup_3471fb11b632143f71e4ced26315cad5 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_6c367fdbf0fdbcc2e4a2cd62dfd
